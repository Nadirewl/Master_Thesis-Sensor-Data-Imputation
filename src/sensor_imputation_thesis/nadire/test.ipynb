# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df=pd.read_parquet("/home/ec2-user/SageMaker/sensor-imputation-thesis/src/sensor_imputation_thesis/nadire/9missingcolsdata.parquet")

# %%
df.describe()
# Out:
#                                 time         fr_eng  te_exh_cyl_out__0  \
# count                         430897  413587.000000      413587.000000
# mean   2024-04-02 18:06:08.558797568       0.579343         467.367613
# min              2023-10-31 00:00:00      -0.691667         287.150000
# 25%              2024-01-14 03:42:00       0.000000         322.150000
# 50%              2024-03-30 02:38:00       0.881667         543.150000
# 75%              2024-06-15 02:21:00       1.031667         569.150000
# max              2024-09-30 23:59:00       1.161667         633.150000
# std                              NaN       0.491547         117.123678
#
#        te_exh_cyl_out__1  te_exh_cyl_out__2  te_exh_cyl_out__3  \
# count      413587.000000      413587.000000      413587.000000
# mean          462.747391         474.538027         478.842531
# min           288.150000         289.150000         289.150000
# 25%           322.150000         325.150000         326.150000
# 50%           537.150000         550.150000         561.150000
# 75%           559.150000         582.150000         583.150000
# max           615.150000         632.150000         641.150000
# std           114.966705         120.058149         123.411919
#
#        te_exh_cyl_out__4  te_exh_cyl_out__5  te_exh_cyl_out__6   pd_air_ic__0  \
# count      413587.000000      413587.000000                0.0  413586.000000
# mean          468.562370         484.326231                NaN    1029.130580
# min           290.150000         288.150000                NaN       0.000000
# 25%           325.150000         326.150000                NaN       0.000000
# 50%           541.150000         568.150000                NaN    1000.000000
# 75%           568.150000         596.150000                NaN    2000.000000
# max           623.150000         657.150000                NaN    3000.000000
# std           115.284706         127.981016                NaN     932.841699
#
#        ...  pr_cyl_max__2  pr_cyl_max__3  pr_cyl_max__4  pr_cyl_max__5  \
# count  ...   2.447890e+05   2.447890e+05   2.447890e+05   2.447890e+05
# mean   ...   1.449609e+07   1.451113e+07   1.449665e+07   1.448251e+07
# min    ...   2.950000e+06   2.970000e+06   2.990000e+06   2.810000e+06
# 25%    ...   1.272000e+07   1.277000e+07   1.276000e+07   1.269000e+07
# 50%    ...   1.464000e+07   1.466000e+07   1.467000e+07   1.466000e+07
# 75%    ...   1.641000e+07   1.643000e+07   1.642000e+07   1.642000e+07
# max    ...   1.912000e+07   1.922000e+07   1.927000e+07   1.928000e+07
# std    ...   2.364256e+06   2.356933e+06   2.398391e+06   2.425657e+06
#
#        pr_cyl_max__6  pr_cyl_max__7  pr_cyl_max__8  pr_cyl_max__9  \
# count            0.0            0.0            0.0            0.0
# mean             NaN            NaN            NaN            NaN
# min              NaN            NaN            NaN            NaN
# 25%              NaN            NaN            NaN            NaN
# 50%              NaN            NaN            NaN            NaN
# 75%              NaN            NaN            NaN            NaN
# max              NaN            NaN            NaN            NaN
# std              NaN            NaN            NaN            NaN
#
#        pr_cyl_max__10  pr_cyl_max__11
# count             0.0             0.0
# mean              NaN             NaN
# min               NaN             NaN
# 25%               NaN             NaN
# 50%               NaN             NaN
# 75%               NaN             NaN
# max               NaN             NaN
# std               NaN             NaN
#
# [8 rows x 60 columns]

# %%
df["te_exh_cyl_out__0"][:10]
# Out:
# 0    524.15
# 1    524.15
# 2    525.15
# 3    525.15
# 4    525.15
# 5    525.15
# 6    525.15
# 7    525.15
# 8    525.15
# 9    525.15
# Name: te_exh_cyl_out__0, dtype: float64

# %%
scaler=StandardScaler()
